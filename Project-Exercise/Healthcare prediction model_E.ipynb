# %%
# Diabetes Prediction (Logistic Regression on Pima dataset structure)
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

# Simulate health data: [Glucose, BMI, Age, BP, etc.]
X, y = make_classification(n_samples=768, n_features=8, n_classes=2,
                           weights=[0.65, 0.35], random_state=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_proba = rf.predict_proba(X_test)[:, 1]

print("AUC-ROC Score:", roc_auc_score(y_test, y_proba))
