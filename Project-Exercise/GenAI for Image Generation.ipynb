# %%
# Placeholder for Image Gen Demo
print(" To generate images:")
print("1. Use Hugging Face Diffusers: `pip install diffusers transformers accelerate`")
print("2. Load Stable Diffusion pipeline:")
print("   from diffusers import StableDiffusionPipeline")
print("   pipe = StableDiffusionPipeline.from_pretrained('runwayml/stable-diffusion-v1-5')")
print("   image = pipe('a futuristic AI academy').images[0]")
print("   image.save('eit_academy.png')")
