# %% [markdown]
# Stage 1 : Problem Definition : Should not be more than 2 or 2.5 lines of text
#
# Stage 2 : Data Collection
#
# Stage 3 : Data Exploration and Profiling
#
# Stage 4 : Data Cleaning and Preprocessing
#
# Stage 5 : Feature Engineering
#
# Stage 6 : Feature Selection / Extraction
#
# Stage 7 : Encoding and Representation
#
# Stage 8 : Train - Test - Split & Validation
#
# Stage 9 : Model Training
#
# Stage 10 : Model Evaluation
#
# State 11 : Model Selection and Finalization
#
# Stage 12 : Model Deployment
#
# Stage 13 : Maintenance and Continuous Learning
#
# Stage 14 : Documentation and Communication

# %%
# The package . library we are going to use for data collection and data manipulation is known 
# as Pandas

# %%
# installing pandas software 

# Please use the following command to install software / library / package 

# !pip install pandas

# %%
# Step-2 after installing any package we need to import that package 

import pandas as pd

# %%
# Find version number of the installed package 
print(f"The installed version of pandas is :{pd.__version__}") # format string
# Out:
# The installed version of pandas is :2.3.3
