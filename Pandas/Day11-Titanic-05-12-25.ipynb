# %%
# !pip3 install -qU pandas  
# !pip3 install -qU numpy
# !pip3 install -qU matplotlib
# !pip3 install -qU seaborn
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.16.2 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.3.5 which is incompatible.

# %%
import pandas as pd #  Data Colletion and Data Manipulation
import numpy as np #  Converting Data into numbers 
import matplotlib.pyplot as plt #  Data Visualization
import seaborn as sns #  Data Visualization

# %%
# Loading Data set 
df = pd.read_csv("/Users/sb/Documents/PyCharm-Work/Trainings/EITA/5AM-AWS-AI/Pandas/titanic.csv")

# %%
# viewing top 5 rows 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail() # viewing last 5 rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# importNT command 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# prniting column names
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 12

# %%
# Viewing data from each column [ series of data]
df['PassengerId']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
df['Name'].count() # count of rows
# Out:
# 891

# %%
df['Name'].unique() # unique values
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
df['Survived'].count() # count of rows
# Out:
# 891

# %%
df['Survived'].unique() # unique values
# Out:
# array([0, 1])

# %%
df['Survived'].value_counts() # count of each unique values]
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Finding statistical data of each column
df['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
df['Survived'].median()
# Out:
# 0.0

# %%
df['Survived'].mode()
# Out:
# 0    0
# Name: Survived, dtype: int64

# %%
df['Survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
df.describe()  # This command shows only column which have numerical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
len(df.describe()) # 8 columns)
# Out:
# 8

# %%
len(df.columns) # 12 columns)
# Out:
# 12

# %%
# REading data from more than one column
df[['PassengerId', 'Survived', 'Pclass']] # List of Lists , [[ ]]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
df[['PassengerId', 'Survived', 'Pclass']].head(10)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2

# %%
df[['PassengerId', 'Survived', 'Pclass']].mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# dtype: float64

# %%
df[['PassengerId', 'Survived', 'Pclass']].dtypes    # dtypes means datatypes
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']].dtypes
# Out:
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df[['Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df[['Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']].mean()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)  11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# ...

# %%
# to fetch information from row wise, we have two commands, they are iloc and loc
df.iloc[700] # 0th row
# Out:
# PassengerId                                                  701
# Survived                                                       1
# Pclass                                                         1
# Name           Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# Sex                                                       female
# Age                                                         18.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17757
# Fare                                                     227.525
# Cabin                                                    C62 C64
# Embarked                                                       C
# Name: 700, dtype: object

# %%
df.iloc[700:710] # 0th row
# Out:
#      PassengerId  Survived  Pclass  \
# 700          701         1       1
# 701          702         1       1
# 702          703         0       3
# 703          704         0       3
# 704          705         0       3
# 705          706         0       2
# 706          707         1       2
# 707          708         1       1
# 708          709         1       1
# 709          710         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 701                   Silverthorne, Mr. Spencer Victor    male  35.0      0
# 702                              Barbara, Miss. Saiide  female  18.0      0
# 703                              Gallagher, Mr. Martin    male  25.0      0
# 704                            Hansen, Mr. Henrik Juul    male  26.0      1
# 705     Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0      0
# ...

# %%
# trying to print data from 3rd column to last and 150 to 155 

df.iloc[150:156, 3:]
# Out:
#                                   Name     Sex   Age  SibSp  Parch  \
# 150         Bateman, Rev. Robert James    male  51.0      0      0
# 151  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1      0
# 152                   Meo, Mr. Alfonzo    male  55.5      0      0
# 153    van Billiard, Mr. Austin Blyler    male  40.5      0      2
# 154              Olsen, Mr. Ole Martin    male   NaN      0      0
# 155        Williams, Mr. Charles Duane    male  51.0      0      1
#
#           Ticket     Fare Cabin Embarked
# 150  S.O.P. 1166  12.5250   NaN        S
# 151       113776  66.6000    C2        S
# 152   A.5. 11206   8.0500   NaN        S
# 153     A/5. 851  14.5000   NaN        S
# 154    Fa 265302   7.3125   NaN        S
# 155     PC 17597  61.3792   NaN        C

# %%
[ Rows : column ]

# %%
#using .loc command 
df.loc[150:155, 'PassengerId':'Pclass']
# Out:
#      PassengerId  Survived  Pclass
# 150          151         0       2
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1

# %%
# Viewing data about age column
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# finding missing values in a column 
df['Age'].isnull().sum()
# Out:
# 177

# %%
#viewing rows that have missing values
df[df['Age'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #viewing rows that have missing values
# ----> 2 df[df['Age'].isnull()]
#
# NameError: name 'df' is not defined

# %%
#  finding duplicate values in age column 
df['Age'].duplicated().sum()
# Out:
# 802

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
# Finding missing values on the df
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# finding duplicated informtion about df 
df.duplicated().sum()
# Out:
# 0

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# want to see only those rows  of people who's age is above 54
df[df['Age'] > 54]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 152          153         0       3
# 170          171         0       1
# 174          175         0       1
# 195          196         1       1
# 232          233         0       2
# 252          253         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 467          468         0       1
# 483          484         1       3
# 487          488         0       1
# 492          493         0       1
# 493          494         0       1
# ...

# %%
# finding rows of people whos age is above 54 and whos gender is male
df([df['Age']>54]) and df['Sex']=='male'])
# Out:
#   Cell In[1], line 2
#     df([df['Age']>54]) and df['Sex']=='male'])
#                                             ^
# SyntaxError: unmatched ']'

# %%
# finding rows of people whos age is above 54 from age column and whos gender is male from Sex column
[(df['Age']>54) & (df['Sex']=='male')]
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  886    False
#  887    False
#  888    False
#  889    False
#  890    False
#  Length: 891, dtype: bool]

# %%
df[(df['Age']>54) & (df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 195          196         1       1
# 268          269         1       1
# 275          276         1       1
# 366          367         1       1
# 483          484         1       3
# 772          773         0       2
# 829          830         1       1
# 879          880         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 195                              Lurette, Miss. Elise  female  58.0      0
# 268     Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# ...

# %%
print(list[df.dtypes])
# Out:
# list[PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object]

# %%
df[(df['Survived']==0 ) & (df['Pclass']==1)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 806          807         0       1                Andrews, Mr. Thomas Jr
# 815          816         0       1                      Fry, Mr. Richard
# 822          823         0       1       Reuchlin, Jonkheer. John George
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df[df['Age'].between(30,40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 13            14         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 867          868         0       1
# 872          873         0       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...
