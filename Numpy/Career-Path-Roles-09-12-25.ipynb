# %%
# Python is PL



# Pandas - > This is for Data Collection and Data MAnipulation : Data Stracture : DataFRame , Series 

# Numpy --> TO convert above data into numerical format such as matrix , vector, scaler and tensor : Ds :- nd. array

# MatPlotLib --> This is a Library related to visualization of data . Bar chart , line chart , pie chart , histogram , scatter plot

# Seaborn --> This is also for visualization, more beautiful charts / graph 

# Scikit-Learn --> This is for Machine Learning Algorithm implementation : Supervised and Unsupervised
                # This is a framework for ML Algorithms : Regression , Classification , Clustering , Dimensionality Reduction
# TensorFlow / PyTorch --> This is for Deep Learning Algorithm implementation : ANN , CNN , RNN , LSTM
#  # Tensforflow --> Developed by Google
#  # PyTorch --> Developed by Facebook / Meta 
                # This is a framework for DL Algorithms : Image Processing , Natural Language Processing , Speech Recognition
# LangChain --> This is a framework for Generative AI and LLMs : To build applications using LLMs : Chatbots , Text Generation , Summarization , Q&A Systems

# %%
# We have different roles in market :
# Data Engineer  
# ML Engineer  
# DL Engineer  
# Generative AI Engineer  
# Ai Engineer  
# MLOps Engineer  
# Computer Vision Engineer / Expert 
# NLP Engineer / Expert / Researcher/Specialist
# AI Researcher
# AI Scientist
# AI Architect  
# AI Consultant  
# AI Developer
# AI Trainer  
# AI Product Manager  
# AI Ethicist  
# AI Strategist  
# AI Analyst  
# AI Operations Manager  
#Solutions Architect 

# Data Science : 
# # Machine  Learning Engineer                            # Data Engineer         # ML Ops Engineer
# # Deep Learning Engineer                                # Data Roles            # LLM Ops Engineer   
# # Generative AI Engineer   
# # Computer Vision Engineer  
# 
# # Model Development Roles                              # Data Science Roles   

# By the time we start Scikit-Learn , prepare yourself  for roles / journey into 
# 1) ML (ML & DL )
# 2) DL 
# 3) Computer Vision ( CVE)
# 4) Gen-AI
# 5) Data Engineering

# Identify Interests and choose your path accordingly [ IT Industry , 
# Entertainment Industry , 
# Healthcare Industry , 
# Finance Industry , 
# Retail Industry , 
# Manufacturing Industry , 
# Automotive Industry 
# Education Industry , 
# Agriculture Industry , 
# Energy Industry , 
# Telecommunications Industry ,
# # Sports Industry ,


# In that industrey , start collecting major / medium / small and startup comapnies 
# Various Job Roles in those companies
# Identify the skills required for those roles

# Prepare a couple of Resumes 

#) Machine Learning Roles , use 1 copy of Resume
#) Deep Learning Roles , another format of Resume
#) Generative AI Roles , another format of Resume
#) Data Engineering Roles , another format of Resume

# %%
#
