# %% [markdown]
# 1. What are data pre-processing functions / tools we have in scikit-learn ?
#
# 1. StandardScalar -> [mean =0, std=1] -
# 2. MinMaxScalar ->
# 3. Binarizer -- >
# 4. LabelEncoder --> (0,1)
# 5. OneHotEncoder --> to handle cat values ()
# 6. SimpleImputer --> fill missing value[]
# 7. KnnImputer -->

# %%
2. Explain various evaluation functions we haev in scikt-learn ?
1. train_test_split
2. cross_val_score
3. Mean Squared Error
4. R2 score
5. Classification_report 
6. Confusion_matrix
7. Accuracy_score

# %%
Q3. Tell me list of regression models in scikit-learn ? [ Supervised-Regression]
1. LinearRegression
2. Ridge
3. Lasso
4. ElasticNet
5. PolynomialRegression
6. MultiLinearRegression
7. SVR [ support vector machine]

# %%
# How do we import above algorithms in scikit-learn ?
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import MultiLinearRegression
from sklearn.svm import SVR

# %%
# from 5am-awa-ai.machine_learning import interview
from 5am_aws_ai.machine_learning import raj

# %%
from 5am_aws_ai.machine_learning import raj

# %%
# wrtei unsupervised learning Algo

from sklearn.decomposition import PCA
