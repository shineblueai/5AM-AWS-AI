# %% [markdown]
# Pandas - Data Collectio and Data Manipulation
# Numpy - TO convert data into numbers
# MAtplotlib - Visualiztion
# Seaborn - Visualiztion
# Scikit-Learn - Machine Learning Framework
# Code : PNM SS
# P- Pandas
# N - Numpy
# M - Matplotlib
# S - Seaborn
# S - Scikit Learn [ While installing we will call it as scikit-learn , while using we will call it as sklearn ]

# %%
# Define MAchine LEarning :  The ability to learn everything by itself without any external help is known as machine learning 
# Machine Learning 
Supervised Learning
i) - Classification - > Anything which is a discrete variable is known as classification type Ex: Yes/No, Male/Female
ii) - Regression --> Anything which is a continuous variable is known as regression type - Ex : range of numbers  -1000$-1545.55
Keyword : Label  Datan

Unsupervised Learning
i) - Clustering -- >Grouping of data based on some similarity or pattern
ii) A- Association -- > 
Keyword : Unlabelled Data / Pattern / Similarity

# %%
# REgression : Relation (X , y) : Dataset : features (column name, data, label, feature)
# House Price : Location, bedroom , east , price [ Dependednt (y) / Independent ( X) ]
X - y

# %% [markdown]
# # Steps of Model Creation : Code - ILC MST CPP E
# I- Import Libraries [ PNM SS] [8 -imports ]
#     P -Pandas, N - Numpy M -Matplotlib S- Seaborn S Sklearn
#
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     import sklearn
#     from sklearn.model_selction import LinearRegression /
#     from sklearn.metrics import r2_score, MSE, MAE ,
#     from sklearn.moedl_slection import train_test_split
#
#
# L - Load Dataset
#     pd.read_csv("file name with path")
#     pd.read_excel(" file name with path)
#     pd.read_html('Url address)
#
#
# C - Check DataTypes
#     df.dtypes
#     df.info()
#
# M - Missing data Handling [ Exploratory Data Analysis -EDA ]
#     df.isnull().sum()
#     df.duplicated().sum()
#     df.describe()
#     outliers
#     plot
#     change datatype / rename / imputatio technique / simpleImputer/ KnnImputer /
#
#
# S - X,y split [ Ind / Dep]
#     X = [[" " ]] -DataFrame / 2-d / data / column name / feature
#     y = [ ] -> target /output / label
#     Formula for Linear Regresion -> y = mx+c
#
#
# T - Train- test - split
#     import train-test-split [ from sklearn]
#
# C - Create , call, Train[fit]
#    lr = LinearRegression()
#    Lr = LogisticRegression()
#    lr.fit_transform()
#
# P - Predict with Model
#    y_pred = lr.predict( X_test)
# P - Plot Model
#     Scatterplot
#     lineplot
#     title
#     x-label
#     y-axis
#     tigh-layout
#     plt.show()
#
#
# E - Evaluate the model
#     Mean Squared Error / MSE / Clasification_sore /
