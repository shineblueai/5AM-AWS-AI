# %% [markdown]
# Pre-Processing Steps
#
# 1. import libraries
# 2. missing data handling
# 3. remove dup
# 4. outliers
# 5. data type handling [ int -str]

# %%
Feature Eng -Feature Selection ?
classification type - - class, student number - []

# %% [markdown]
# # Encoding -Rep -
#
# str - unstr - images , video- sms , email , document-numerical
# python -map / zip
# sklearn- labelencoder, ohe,

# %%
train-test-split = 

Model -Eval - MSE - MAE -RMSE -Classification, confu_mat
