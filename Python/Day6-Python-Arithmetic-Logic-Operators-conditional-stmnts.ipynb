# %%
# Working with Python Math-Operations

2 +3
# Out:
# 5

# %%
2-3

# %%
2*3
# Out:
# 6

# %%
2 / 3
# Out:
# 0.6666666666666666

# %%
2 ** 3
# Out:
# 8

# %%
BODMAS (Bracker open , div, Mul,Addi, - )

# %%
5 + 2 * 3 - 4 / 6

# %%
# Mod Operator
8 % 4
# Out:
# 0

# %%
# Working with Comparison Operators

A = 5
# Out:
#   Cell In[10], line 3
#     3 = 5
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
4 != 5
# Out:
# True

# %%
# Working with Logical Operators

(3 > 2) and (1 > 3)
# Out:
# False

# %%
# Working with conditional stmnts

# In Python we have 3 types of conditional statments

#1. if
    ## if-else
      ### if-elif-else [ elif = else  if ]

#2. for

#3. while

# %%
# Working with if condi stmnts

# if
# Syntax :
#if (condition):
#    print("Hello World")

# %%
# If works only when given condition is True

if 4 > 5:
    print( " 4 is greater than 5")
# Out:
#  4 is greater than 5

# %%
if 4 > 5 :
    print("4 is greater than 5")
else  :
    print("5 is greater than 4")
# Out:
# 5 is greater than 4
