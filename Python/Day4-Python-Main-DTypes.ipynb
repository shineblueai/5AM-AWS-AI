# %%
# The main datatypes are
# List, # Tuple # Dict, # str

# %%
# Working with str datatype : Anything enclosed within a pair or '' or ""

# %%
text = "I am learning Python"

# %%
# Some of the functions or methods we can use on str datatype
# .upper()
# .lower()
# .capitalize()
# .title()
# .swapcase()
# .find()
# .count()
# .index()
# .isalpha()
# .isdigit()
# .split()
# .join()
# .strip()
# .replace()
# .encode()
# .decode()

# %%
print(text)
# Out:
#  I am learning Python

# %%
# working with .upper()
# Syn: How to use a  command : variable_name.method()
upper_text = text.upper()
print(upper_text)
# Out:
#  I AM LEARNING PYTHON

# %%
# Working with .lower()
print(upper_text.lower())
# Out:
#  i am learning python

# %%
# Working with .capitalize() #  will make first letter capital
#print(text.capitalize())
text.capitalize()
# Out:
# 'I am learning python'

# %%
# Working with .title() , it would capitalize the first letter of every word
print(text.title())
# Out:
# I Am Learning Python

# %%
# Question , what happens if change text inside our variable

# %%
# HA : Please work with .swapcase()

# %%
# Working with .count() # it would count the number of times a particular character is present in the string
text.count("I")
# Out:
# 1

# %%
# working with .count()
print(text.count("n"))
# Out:
# 3

# %%
# Working with .index()
text.index("P")
# Out:
# 14

# %%
# working with .split()
text.split()
# Out:
# ['I', 'am', 'learning', 'Python']

# %%
text = "I am learning Machine Learning"

# %%
print(text)
# Out:
# I am learning Machine Learning

# %%
text ="I am learning Python, Machine Learning , Deep Learning, Gen AI"

# %%
print(text)
# Out:
# IamlearningPython, Machine Learning , Deep Learning, Gen AI

# %%
split_text = (text.split(" "))
print(split_text)
# Out:
# ['I', 'am', 'learning', 'Python,', 'Machine', 'Learning', ',', 'Deep', 'Learning,', 'Gen', 'AI']

# %%
# working with .join()
' '.join(split_text)
# Out:
# 'I am learning Python, Machine Learning , Deep Learning, Gen AI'

# %%
# working with .split()
print(text.split("---------"))
# Out:
# ['I am learning Python, Machine Learning , Deep Learning, Gen AI']

# %%
# how do I get help on any command

# %%
new_line = "I*am@learning@DS"

# %%
print(new_line.split("*"))
# Out:
# ['I', 'am@learning@DS']

# %%
# .join, .split, .strip
