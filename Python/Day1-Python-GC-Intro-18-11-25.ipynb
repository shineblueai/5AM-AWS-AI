# %%
IDE = Integrated Development Env

# %% [markdown]
# # .ipynb = Interactive(I) Python(py) Notebook(nb)

# %%
print("Welcome to DS-AI- Master Course")
# Out:
# Welcome to DS-AI- Master Course

# %% [markdown]
# ### Today we have learnt how to use Google Colab
#
#
#
# 1.   Python
# 2.   Pandas

# %% [markdown]
# 1.   Python --->
# 2.   Pandas ---> Deal with Data
# 3.   Numpy  ---> To Convert data into numbers
# 4.   MatPlotLib --> Visualize , we can create chart / graph / plot
# 5.   Seaborn --->   Visulization Tool
# 6.   Scikit - Learn --> Learning Machine Learning Alg [ SCikit-Learn is the FW]
# 7.   Types of MAchine Learning - Supervised, Unsupervised,
# 8.   Working on alg , wrting programs and creating projects
# 9.   Deep Learning - [ Another framework for DL] , Tensorflow, Pytorch
# 10.  Perceptrob, MLP, ANN, CNN, RNN, RNN-LSTM, GRU, Transformers
# 11.  Gen-AI : Creating GPT, chat GPT, Web Applications,with DB
# 12.  ALl models in gen -ai, HuggingFace, RunPod, OpenRouter, OpenAI, Google BERT
# 13.  LLM - Large Language Models - Applications
# 14.  We need create resume, we need push to projects to github
# 15.  TEchnical interviews, Which companies, which domain, which industries,
# 16.  Open Job posting, how to prep our resume
# 17.  CErtifications , AWS, Azure, GCP,
# 18.  Visual Code , Pycharm
# 19.  Vrious tools with cloud provides in connection AI/ ML / DL / Gen AI
